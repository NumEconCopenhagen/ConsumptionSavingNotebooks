# %% [markdown]
# # A Guide On Solving Non-Convex Consumption-Saving Models

# %% [markdown]
# This notebook produces the timing and accuracy results for the benchmark model in [A Guide On Solving Non-Convex Consumption-Saving Model](https://www.dropbox.com/s/dzgoo5ywmlrecbk/WP_NEGM_2020.pdf?dl=0).

# %% [markdown]
# # Setup

# %%
from consav import runtools
runtools.write_numba_config(disable=0,threads=8)

# %%
import time
import itertools as it
import numpy as np
from copy import copy

# %matplotlib inline

# reload module each time cell is run
# %load_ext autoreload
# %autoreload 2

# load the DurableConsumptionModel module
from DurableConsumptionModel import DurableConsumptionModelClass

# %% [markdown]
# # Timing function

# %%
def run(name = 'baseline',
        rep = 5,
        load = False,
        solmethod = 'negm_cpp',
        updpar = {},
        do_simple_wq = False,
        do_print = False):
    
    # a. create model
    model = DurableConsumptionModelClass(name=name,load=load,solmethod=solmethod,
                                         do_print=do_print,do_simple_wq=do_simple_wq,**updpar)
    
    # b. run
    if load == False:
        
        # i. precompile
        if solmethod not in ['vfi_cpp','nvfi_cpp','negm_cpp']:
            model.precompile_numba()        
        
        # ii. best of three
        best_time = np.inf
        for it in range(rep):
            
            model.solve()
            total_time = np.sum(model.par.time_w+model.par.time_keep+model.par.time_adj)
            
            if total_time < best_time:
            
                best_time = total_time
                time_w = model.par.time_w.copy()
                time_keep = model.par.time_keep.copy()
                time_adj= model.par.time_adj.copy()
            
            print(f'{it}: total time = {total_time:.2f}')
                
        # iii. collect infomation
        model.simulate(do_euler_error=True,do_utility=True)
        model.par.time_w = time_w.copy()
        model.par.time_keep = time_keep.copy()
        model.par.time_adj= time_adj.copy()
        model.save()    

    # c. print progress
    print('')    
    model.print_analysis()        
    model.checksum(simple=True)
    print('')
    
    return model

# %% [markdown]
# # Settings

# %%
load = False
load_negm = load
load_negm_cpp = load
load_negm_cpp_simple = load
load_nvfi = load
load_nvfi_cpp = load
load_nvfi_cpp_simple = load
load_vfi = load
load_vfi_cpp = load

T = 50
models = dict()

# baseline
basename = 'results'
base = dict()
base['Np'] = 150
base['Nn'] = 150
base['Nm'] = 300
base['Nx'] = 300
base['Na'] = 300
base['T'] = T

# %% [markdown]
# # Timings

# %%
models['negm_cpp'] = run(name=f'{basename}',load=load_negm_cpp,solmethod='negm_cpp',updpar=base)
models['negm_cpp_simple'] = run(name=f'{basename}_simple',load=load_negm_cpp_simple,solmethod='negm_cpp',do_simple_wq=True,updpar=base)
models['negm'] = run(name=f'{basename}',load=load_negm,solmethod='negm',updpar=base)

models['nvfi_cpp'] = run(name=f'{basename}',load=load_nvfi_cpp,solmethod='nvfi_cpp',updpar=base)
models['nvfi_cpp_simple'] = run(name=f'{basename}_simple',load=load_nvfi_cpp_simple,solmethod='nvfi_cpp',do_simple_wq=True,updpar=base)
models['nvfi'] = run(name=f'{basename}',load=load_nvfi,solmethod='nvfi',updpar=base)

models['vfi_cpp'] = run(name=f'{basename}',load=load_vfi_cpp,solmethod='vfi_cpp',updpar=base)
# Out:
# 0: total time = 79.76
# 1: total time = 79.92
# 2: total time = 79.81
# 3: total time = 79.97
# 4: total time = 79.48
#
# Name: results (solmethod = negm_cpp)
# Grids: (p,n,m,x,a) = (150,150,300,300,300)
# Timings:
#  total: 79.5
#      w: 46.2
#   keep: 32.5
#    adj: 0.8
# Utility: -32.213469
# Euler errors:
#      total: -4.71 (-5.30,-4.03)
#    keepers: -4.68 (-5.30,-3.97)
#  adjusters: -4.89 (-5.30,-4.52)
# Moments:
#  adjuster share: 0.172
#          mean c: 0.979
#           var c: 0.256
#          mean d: 0.562
#           var d: 0.112
#
# checksum, inv_v_keep: 0.03967627
# checksum, inv_v_adj: 0.03973847
#
# 0: total time = 243.97
# 1: total time = 245.18
# 2: total time = 245.71
# 3: total time = 244.49
# 4: total time = 244.77
#
# Name: results_simple (solmethod = negm_cpp)
# Grids: (p,n,m,x,a) = (150,150,300,300,300)
# Timings:
#  total: 244.0
#      w: 210.7
#   keep: 32.5
#    adj: 0.7
# Utility: -32.213469
# Euler errors:
#      total: -4.71 (-5.30,-4.03)
#    keepers: -4.68 (-5.30,-3.97)
#  adjusters: -4.89 (-5.30,-4.52)
# Moments:
#  adjuster share: 0.172
#          mean c: 0.979
#           var c: 0.256
#          mean d: 0.562
#           var d: 0.112
#
# checksum, inv_v_keep: 0.03967627
# checksum, inv_v_adj: 0.03973847
#
# 0: total time = 137.34
# 1: total time = 138.21
# 2: total time = 138.01
# 3: total time = 138.23
# 4: total time = 138.47
#
# Name: results (solmethod = negm)
# Grids: (p,n,m,x,a) = (150,150,300,300,300)
# Timings:
#  total: 137.3
#      w: 95.9
#   keep: 40.1
#    adj: 1.4
# Utility: -32.213469
# Euler errors:
#      total: -4.71 (-5.30,-4.03)
#    keepers: -4.68 (-5.30,-3.97)
#  adjusters: -4.89 (-5.30,-4.52)
# Moments:
#  adjuster share: 0.172
#          mean c: 0.979
#           var c: 0.256
#          mean d: 0.562
#           var d: 0.112
#
# checksum, inv_v_keep: 0.03967627
# checksum, inv_v_adj: 0.03973847
#
# 0: total time = 280.79
# 1: total time = 281.83
# 2: total time = 281.84
# 3: total time = 281.21
# 4: total time = 282.03
#
# Name: results (solmethod = nvfi_cpp)
# Grids: (p,n,m,x,a) = (150,150,300,300,300)
# Timings:
#  total: 280.8
#      w: 28.5
#   keep: 251.6
#    adj: 0.7
# Utility: -32.213436
# Euler errors:
#      total: -4.61 (-5.32,-3.94)
#    keepers: -4.59 (-5.30,-3.90)
#  adjusters: -4.74 (-5.39,-4.23)
# Moments:
#  adjuster share: 0.172
#          mean c: 0.979
#           var c: 0.256
#          mean d: 0.562
#           var d: 0.112
#
# checksum, inv_v_keep: 0.03967629
# checksum, inv_v_adj: 0.03973852
#
# 0: total time = 357.70
# 1: total time = 361.06
# 2: total time = 359.06
# 3: total time = 359.48
# 4: total time = 359.23
#
# Name: results_simple (solmethod = nvfi_cpp)
# Grids: (p,n,m,x,a) = (150,150,300,300,300)
# Timings:
#  total: 357.7
#      w: 105.8
#   keep: 251.2
#    adj: 0.7
# Utility: -32.213436
# Euler errors:
#      total: -4.61 (-5.32,-3.94)
#    keepers: -4.59 (-5.30,-3.90)
#  adjusters: -4.74 (-5.39,-4.23)
# Moments:
#  adjuster share: 0.172
#          mean c: 0.979
#           var c: 0.256
#          mean d: 0.562
#           var d: 0.112
#
# checksum, inv_v_keep: 0.03967629
# checksum, inv_v_adj: 0.03973852
#
# 0: total time = 433.36
# 1: total time = 423.90
# 2: total time = 425.39
# 3: total time = 424.70
# 4: total time = 426.26
#
# Name: results (solmethod = nvfi)
# Grids: (p,n,m,x,a) = (150,150,300,300,300)
# Timings:
#  total: 423.9
#      w: 55.3
#   keep: 367.2
#    adj: 1.4
# Utility: -32.213436
# Euler errors:
#      total: -4.61 (-5.32,-3.94)
#    keepers: -4.59 (-5.30,-3.90)
#  adjusters: -4.74 (-5.39,-4.23)
# Moments:
#  adjuster share: 0.172
#          mean c: 0.979
#           var c: 0.256
#          mean d: 0.562
#           var d: 0.112
#
# checksum, inv_v_keep: 0.03967629
# checksum, inv_v_adj: 0.03973852
#
# 0: total time = 3800.09
# 1: total time = 3784.86
# 2: total time = 3783.09
# 3: total time = 3784.69
# 4: total time = 3784.42
#
# Name: results (solmethod = vfi_cpp)
# Grids: (p,n,m,x,a) = (150,150,300,300,300)
# Timings:
#  total: 3783.1
#      w: 0.0
#   keep: 3707.6
#    adj: 75.5
# Utility: -32.213431
# Euler errors:
#      total: -4.67 (-5.43,-3.92)
#    keepers: -4.69 (-5.45,-3.93)
#  adjusters: -4.56 (-5.29,-3.87)
# Moments:
#  adjuster share: 0.172
#          mean c: 0.979
#           var c: 0.256
#          mean d: 0.562
#           var d: 0.112
#
# checksum, inv_v_keep: 0.03967635
# checksum, inv_v_adj: 0.03974089

# %% [markdown]
# # Tables

# %%
import tabs

# %%
main_models = [models['vfi_cpp'],models['nvfi_cpp_simple'],models['negm_cpp_simple'],models['nvfi_cpp'],models['negm_cpp']]
tabs.all(main_models,speedup=True)

# %%
main_models = [models['nvfi_cpp'],models['nvfi'],models['negm_cpp'],models['negm']]
tabs.all(main_models,postfix='_python')

# %% [markdown]
# # Figures

# %%
models['negm_cpp'].lifecycle()

# %%
from figs import lifecycle_compare
lifecycle_compare(models['negm_cpp'],'NEGM',models['nvfi_cpp'],'NVFI',do_euler_errors=True)

# %%
lifecycle_compare(models['negm_cpp'],'NEGM',models['vfi_cpp'],'VFI',do_euler_errors=True)

# %%
lifecycle_compare(models['negm_cpp'],'NEGM, C++',models['negm'],'NEGM, Python',do_euler_errors=True)
