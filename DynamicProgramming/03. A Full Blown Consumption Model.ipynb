# %% [markdown]
# # A Full Blow Consumption Model

# %% [markdown]
# 1. Go through the **ConsumptionSaving.pdf** slides
# 2. This notebooks solves the presented model with **vfi** and **egm**
# 3. All the results from the slides are produced here

# %% [markdown]
# # Setup

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import time
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from ConsumptionSavingModel import ConsumptionSavingModelClass

# %% [markdown]
# # VFI

# %%
model_vfi = ConsumptionSavingModelClass(name='test',solmethod='vfi')
print(model_vfi)
# Out:
# Modelclass: ConsumptionSavingModelClass
#
# Parameters:
#  T = 200 [int64]
#  TR = 200 [int64]
#  age_min = 25 [int64]
#  rho = 2.0 [float64]
#  beta = 0.96 [float64]
#  G = 1.02 [float64]
#  sigma_xi = 0.1 [float64]
#  sigma_psi = 0.1 [float64]
#  pi = 0.005 [float64]
#  mu = 0.0 [float64]
#  L = array(float64, 1d, C) with shape = (200,)
#  R = 1.04 [float64]
#  borrowingfac = 0.0 [float64]
#  a_max = 20.0 [float64]
#  a_phi = 1.1 [float64]
#  m_max = 20.0 [float64]
#  m_phi = 1.1 [float64]
#  Nxi = 8 [int64]
#  Npsi = 8 [int64]
#  Na = 500 [int64]
#  Nm = 100 [int64]
#  sim_mini = 2.5 [float64]
#  simN = 100000 [int64]
#  simT = 100 [int64]
#  simlifecycle = 0 [int64]
#  psi_vec = array(float64, 1d, C) with shape = (72,)
#  xi_vec = array(float64, 1d, C) with shape = (72,)
#  w = array(float64, 1d, C) with shape = (72,)
#  Nshocks = 72 [int64]
#  a_min = array(float64, 1d, C) with shape = (200,)
#  grid_a = array(float64, 2d, C) with shape = (200, 500)
#  grid_m = array(float64, 2d, C) with shape = (200, 100)
#  FHW = 0.9807692307692307 [float64]
#  AI = 0.9991996797437437 [float64]
#  GI = 0.9894527485055061 [float64]
#  RI = 0.9607689228305227 [float64]
#  WRI = 0.06793662204867575 [float64]
#  FVA = 0.9506354513733356 [float64]
# memory, gb: 0.0
#
# Solution:
#  m = array(float64, 2d, C) with shape = (200, 100)
#  c = array(float64, 2d, C) with shape = (200, 100)
#  inv_v = array(float64, 2d, C) with shape = (200, 100)
# memory, gb: 0.0
#
# Simulation:
#  m = array(float64, 2d, C) with shape = (100000, 100)
#  c = array(float64, 2d, C) with shape = (100000, 100)
#  a = array(float64, 2d, C) with shape = (100000, 100)
#  p = array(float64, 2d, C) with shape = (100000, 100)
#  y = array(float64, 2d, C) with shape = (100000, 100)
#  psi = array(float64, 2d, C) with shape = (100000, 100)
#  xi = array(float64, 2d, C) with shape = (100000, 100)
#  P = array(float64, 2d, C) with shape = (100000, 100)
#  Y = array(float64, 2d, C) with shape = (100000, 100)
#  M = array(float64, 2d, C) with shape = (100000, 100)
#  C = array(float64, 2d, C) with shape = (100000, 100)
#  A = array(float64, 2d, C) with shape = (100000, 100)
# memory, gb: 1.0

# %%
model_vfi.solve()
model_vfi.simulate()
# Out:
# model solved in 11.1 secs
# model simulated in 3.5 secs

# %%
model_vfi.plot_consumption_function_convergence()

# %% [markdown]
# # EGM

# %%
model_egm = ConsumptionSavingModelClass(name='test',solmethod='egm')
print(model_vfi)
# Out:
# Modelclass: ConsumptionSavingModelClass
#
# Parameters:
#  T = 200 [int64]
#  TR = 200 [int64]
#  age_min = 25 [int64]
#  rho = 2.0 [float64]
#  beta = 0.96 [float64]
#  G = 1.02 [float64]
#  sigma_xi = 0.1 [float64]
#  sigma_psi = 0.1 [float64]
#  pi = 0.005 [float64]
#  mu = 0.0 [float64]
#  L = array(float64, 1d, C) with shape = (200,)
#  R = 1.04 [float64]
#  borrowingfac = 0.0 [float64]
#  a_max = 20.0 [float64]
#  a_phi = 1.1 [float64]
#  m_max = 20.0 [float64]
#  m_phi = 1.1 [float64]
#  Nxi = 8 [int64]
#  Npsi = 8 [int64]
#  Na = 500 [int64]
#  Nm = 100 [int64]
#  sim_mini = 2.5 [float64]
#  simN = 100000 [int64]
#  simT = 100 [int64]
#  simlifecycle = 0 [int64]
#  psi_vec = array(float64, 1d, C) with shape = (72,)
#  xi_vec = array(float64, 1d, C) with shape = (72,)
#  w = array(float64, 1d, C) with shape = (72,)
#  Nshocks = 72 [int64]
#  a_min = array(float64, 1d, C) with shape = (200,)
#  grid_a = array(float64, 2d, C) with shape = (200, 500)
#  grid_m = array(float64, 2d, C) with shape = (200, 100)
#  FHW = 0.9807692307692307 [float64]
#  AI = 0.9991996797437437 [float64]
#  GI = 0.9894527485055061 [float64]
#  RI = 0.9607689228305227 [float64]
#  WRI = 0.06793662204867575 [float64]
#  FVA = 0.9506354513733356 [float64]
# memory, gb: 0.0
#
# Solution:
#  m = array(float64, 2d, C) with shape = (200, 100)
#  c = array(float64, 2d, C) with shape = (200, 100)
#  inv_v = array(float64, 2d, C) with shape = (200, 100)
# memory, gb: 0.0
#
# Simulation:
#  m = array(float64, 2d, C) with shape = (100000, 100)
#  c = array(float64, 2d, C) with shape = (100000, 100)
#  a = array(float64, 2d, C) with shape = (100000, 100)
#  p = array(float64, 2d, C) with shape = (100000, 100)
#  y = array(float64, 2d, C) with shape = (100000, 100)
#  psi = array(float64, 2d, C) with shape = (100000, 100)
#  xi = array(float64, 2d, C) with shape = (100000, 100)
#  P = array(float64, 2d, C) with shape = (100000, 100)
#  Y = array(float64, 2d, C) with shape = (100000, 100)
#  M = array(float64, 2d, C) with shape = (100000, 100)
#  C = array(float64, 2d, C) with shape = (100000, 100)
#  A = array(float64, 2d, C) with shape = (100000, 100)
# memory, gb: 1.0

# %%
model_egm.solve()
model_egm.simulate()
# Out:
# model solved in 2.7 secs
# model simulated in 3.3 secs

# %% [markdown]
# # Compare

# %% [markdown]
# **Consumption Functions:**

# %%
fig = plt.figure(figsize=(6,4),dpi=100)
ax = fig.add_subplot(1,1,1)

ax.plot(model_vfi.sol.m[0],model_vfi.sol.c[0],label='VFI')
ax.plot(model_egm.sol.m[0],model_egm.sol.c[0],'-',label='EGM')

ax.legend(frameon=True)

# %% [markdown]
# **Distributions:**

# %%
fig = plt.figure(figsize=(6,4),dpi=100)
ax = fig.add_subplot(1,1,1)

ax.hist(model_vfi.sim.m[:,-1],alpha=0.50,label='VFI',bins=100)
ax.hist(model_egm.sim.m[:,-1],alpha=0.50,label='EGM',bins=100)

ax.legend(frameon=True)

# %% [markdown]
# # Results from slides

# %% [markdown]
# **What to do?**

# %%
BASELINE = True
DO_PERFECT_FORESIGHT = BASELINE
DO_BUFFER_STOCK = BASELINE
DO_LIFE_CYCLE = BASELINE

# %% [markdown]
# **Note:** The ConSav package can be installed with: ```pip install git+https://github.com/NumEconCopenhagen/ConsumptionSaving```

# %% [markdown]
# ## Perfect forsight

# %%
names = ['pf_con_baseline','pf_con_notGI_FHW_RIC','pf_con_GI_notFHW_RIC','pf_con_GI_notFHW_notRIC'] 

if DO_PERFECT_FORESIGHT:
    
    model = ConsumptionSavingModelClass(name='',solmethod='egm')
    for i,name in enumerate(names):

        print(name)

        # a. setup and solve
        model.name = name
        par = model.par

        # detailed solution
        par.T = 200
        par.Na = 10000
        par.a_max = 500
        par.a_phi = 1.1

        # no uncertainty
        par.sigma_xi = 0
        par.sigma_psi = 0
        par.pi = 0 
        par.Npsi = 1
        par.Nxi = 1

        # no borrowing
        par.borrowingfac = 0

        # simulation settings
        par.simN = 1
        par.sim_mini = 50

        # b. changing parameters
        if name == 'pf_con_baseline':
            par.G = 1.03
            par.R = 1.04
            par.beta = 0.96     
        elif name == 'pf_con_notGI_FHW_RIC':
            par.G = 1.00
            par.R = 1.03
            par.beta = 0.98          
        elif name == 'pf_con_GI_notFHW_RIC':
            par.G = 1.035
            par.R = 1.03
            par.beta = 0.95                  
        elif name == 'pf_con_GI_notFHW_notRIC':
            par.R = 0.98
            par.G = 1.03
            par.beta = 0.99 

        # c. solve and simulate
        model.allocate()
        model.solve()                
        model.simulate()

        # d. figures
        model.plot_consumption_function_convergence()
        model.plot_buffer_stock_target()
        if par.FHW < 1 and par.RI < 1:
            model.plot_consumption_function_pf()
        model.plot_simulate_consumption_growth()    

        # e. MPC
        MPC = np.diff(model.sol.c[0,:])/np.diff(model.sol.m[0,:])
        print(f'MPC for m->inf: {MPC[-1]:.3f}')
        
        plt.show()
        print('')
# Out:
# pf_con_baseline
# model solved in 1.9 secs
# model simulated in 1.6 secs
# MPC for m->inf: 0.040
# pf_con_notGI_FHW_RIC
# model solved in 0.3 secs
# model simulated in 0.0 secs
# MPC for m->inf: 0.025
# pf_con_GI_notFHW_RIC
# model solved in 0.4 secs
# model simulated in 0.0 secs
# MPC for m->inf: 0.042
# pf_con_GI_notFHW_notRIC
# model solved in 0.4 secs
# model simulated in 0.0 secs
# MPC for m->inf: 0.015

# %% [markdown]
# ## Buffer-stock

# %%
names = ['baseline','RI_notGI_FHW','RI_GI_notFHW','notRI_GI_notFHW','highrisk']

if DO_BUFFER_STOCK:
    
    model = ConsumptionSavingModelClass(name='',solmethod='egm')    
    par = model.par
    for i,name in enumerate(names):

        print(name)

        # a. setup and solve    
        model.name = name

        # detailed solution
        par.T = 200
        par.Na = 10000
        par.a_max = 500
        par.a_phi = 1.3

        # b. changing parameters
        if name in ['baseline','highrisk']:
            par.G = 1.03
            par.R = 1.04
            par.beta = 0.96
            if name == 'highrisk':
                par.sigma_psi = 0.15
        elif name == 'RI_notGI_FHW':
            par.G = 0.98
            par.R = 1.03
            par.beta = 0.95
        elif name == 'RI_GI_notFHW':
            par.G = 1.04
            par.R = 1.03
            par.beta = 0.96
        elif name == 'notRI_GI_notFHW':
            par.G = 1.00
            par.R = 0.98
            par.beta = 0.98           

        # c. solve and simulate
        model.allocate()
        model.solve()
        model.simulate()

        # d. numbers and figures
        model.plot_value_function_convergence()
        model.plot_consumption_function_convergence()    
        model.plot_buffer_stock_target()
        if par.FHW < 1 and par.RI < 1:
            model.plot_consumption_function_pf()    
        model.plot_simulate_cdf_cash_on_hand()
        model.plot_simulate_consumption_growth()    

        # e. MPC
        MPC = np.diff(model.sol.c[0,:])/np.diff(model.sol.m[0,:])
        print(f'MPC for m->inf: {MPC[-1]:.3f}')
        
        plt.show()
        print('')
# Out:
# baseline
# model solved in 20.4 secs
# model simulated in 3.4 secs
# MPC for m->inf: 0.040
# RI_notGI_FHW
# model solved in 21.3 secs
# model simulated in 2.8 secs
# MPC for m->inf: 0.040
# RI_GI_notFHW
# model solved in 18.1 secs
# model simulated in 2.0 secs
# MPC for m->inf: 0.037
# notRI_GI_notFHW
# model solved in 19.9 secs
# model simulated in 2.1 secs
# MPC for m->inf: 0.007
# highrisk
# model solved in 19.1 secs
# model simulated in 2.1 secs
# MPC for m->inf: 0.040

# %% [markdown]
# ## Life-Cycle

# %%
if DO_LIFE_CYCLE:
    
    model = ConsumptionSavingModelClass(name='lifecycle',solmethod='egm') 
    par = model.par

    # a. life-cycle settings
    par.T = 90-par.age_min;
    par.TR = 65-par.age_min;
    par.simT = par.T;
    par.simlifecycle = 1;

    # b. income profile
    par.L[:par.TR] = np.linspace(1,1/(par.G),par.TR)
    par.L[par.TR-1] = 0.90
    par.L[par.TR-1:] = par.L[par.TR-1:]/par.G

    # c. solve and simulate
    model.allocate()
    model.solve()
    model.simulate()

    # d. figures
    model.plot_consumption_function_convergence_age()
    model.plot_life_cycle_income()
    model.plot_life_cycle_cashonhand()
    model.plot_life_cycle_consumption()
    model.plot_life_cycle_assets()
# Out:
# model solved in 1.8 secs
# model simulated in 3.1 secs
